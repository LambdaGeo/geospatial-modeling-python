# %% [markdown]
# # Chapter 27: Running Models with the DisSModel Platform
#
# *Part IV — DisSModel in Practice*

# %% [markdown]
# ## Learning Objectives
#
# By the end of this chapter you will be able to:
#
# - Deploy models to the DisSModel Cloud Platform
# - Manage authentication and API tokens
# - Monitor simulation execution remotely

# %%
# Standard imports
import numpy as np
import pandas as pd

# %% [markdown]
# ## 24.1 Platform Overview
#
# *TODO: write content.*

# %% [markdown]
# ## Exercises
#
# *TODO: write content.*

# %% [markdown]
# ## Summary
#
# *TODO: summarise key takeaways.*
