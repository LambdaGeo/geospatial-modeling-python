# %% [markdown]
# # Chapter 30: Migrating from TerraME/LUCCME to DisSModel
#
# *Part VII — Scaling, Migration & Reference*

# %% [markdown]
# ## Learning Objectives
#
# By the end of this chapter you will be able to:
#
# - Translate TerraME/LUCCME concepts to their DisSModel equivalents
# - Know what numerical equivalence guarantees already exist
# - Plan an incremental migration of an existing model

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Why Migrate
#
# *TODO: write content.*

# %%
# Code for section: Why Migrate

# %% [markdown]
# ## General Equivalence Table
#
# *TODO: write content.*

# %%
# Code for section: General Equivalence Table

# %% [markdown]
# ## Step-by-Step Incremental Migration
#
# *TODO: write content.*

# %%
# Code for section: Step-by-Step Incremental Migration

# %% [markdown]
# ## Existing Validation Cases in the Ecosystem
#
# *TODO: write content.*

# %%
# Code for section: Existing Validation Cases in the Ecosystem

# %% [markdown]
# ## Exercises
#
# *TODO: write content.*

# %%
# Code for section: Exercises

# %% [markdown]
# ## Summary
#
# *TODO: summarise key takeaways.*
#
# ### Key concepts introduced
#
# - TODO
# - TODO
# - TODO

# %% [markdown]
# ## Further Reading
#
# - *TODO: add references.*
