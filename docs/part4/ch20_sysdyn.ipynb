# %% [markdown]
# # Chapter 20: System Dynamics with DisSModel
#
# *Part IV — DisSModel: Core and Paradigms*

# %% [markdown]
# ## Learning Objectives
#
# By the end of this chapter you will be able to:
#
# - Install and explore the dissmodel-sysdyn model library
# - Understand stocks, flows, and feedback loops
# - Recognize the categories of available system dynamics models

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Installation and Quick Start
#
# *TODO: write content.*

# %%
# Code for section: Installation and Quick Start

# %% [markdown]
# ## Included Models by Category
#
# *TODO: write content.*

# %%
# Code for section: Included Models by Category

# %% [markdown]
# ## Theory: Stocks and Flows
#
# *TODO: write content.*

# %%
# Code for section: Theory: Stocks and Flows

# %% [markdown]
# ## Feedbacks: Balancing and Reinforcing
#
# *TODO: write content.*

# %%
# Code for section: Feedbacks: Balancing and Reinforcing

# %% [markdown]
# ## Epidemiology: The SIR Model
#
# *TODO: write content.*

# %%
# Code for section: Epidemiology: The SIR Model

# %% [markdown]
# ## Chaos and Sensitivity to Initial Conditions
#
# *TODO: write content.*

# %%
# Code for section: Chaos and Sensitivity to Initial Conditions

# %% [markdown]
# ## Predator-Prey and Phase-Plane Analysis
#
# *TODO: write content.*

# %%
# Code for section: Predator-Prey and Phase-Plane Analysis

# %% [markdown]
# ## Daisyworld and the Gaia Hypothesis
#
# *TODO: write content.*

# %%
# Code for section: Daisyworld and the Gaia Hypothesis

# %% [markdown]
# ## Exercises
#
# *TODO: write content.*

# %%
# Code for section: Exercises

# %% [markdown]
# ## Summary
#
# *TODO: summarise key takeaways.*
#
# ### Key concepts introduced
#
# - TODO
# - TODO
# - TODO

# %% [markdown]
# ## Further Reading
#
# - *TODO: add references.*
